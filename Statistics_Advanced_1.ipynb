# %% [markdown]
# 1. What is a random variable in probability theory?
# - A random variable is a numerical value assigned to the outcome of a random experiment.
# - Example:
# Rolling a die → random variable 𝑋 X = number on the top face.
#
# 2. What are the types of random variables?
# - There are two main types:
# - Discrete random variables → take countable values (0, 1, 2, 3, …)
# - Continuous random variables → take any value within a range (e.g., 2.34, 2.341, …)
#
# 3. Explain the difference between discrete and continuous distributions
# - | Feature      | Discrete            | Continuous                     |
# | ------------ | ------------------- | ------------------------------ |
# | Values       | Countable           | Infinite values in an interval |
# | Example      | Number of customers | Customer waiting time          |
# | Probability  | P(X = x) > 0        | P(X = x) = 0                   |
# | Distribution | PMF                 | PDF                            |
#
#
# 4. What is a binomial distribution, and how is it used in probability?
# - The binomial distribution models the number of successes in a fixed number of independent trials with only two outcomes (success/failure).
#
# - Used when:
# - Fixed number of trials
# 𝑛
# n
# - Each trial has probability
# 𝑝
# p
# - Outcomes are independent
#
# 5. What is the standard normal distribution, and why is it important?
# - The standard normal distribution is a normal distribution with:
#
#   - Mean = 0
#
#   - Standard deviation = 1
#
# - It’s important because:
#
#   - Any normal distribution can be converted into it using Z-scores
#
#   - Probability tables are based on it
#
# 6. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# - The Central Limit Theorem states that:
#
#   - For a sufficiently large sample size, the sampling distribution of the sample mean approaches a normal distribution, regardless of the population’s original distribution.
#
# - Why it’s critical:
#
#   - Allows use of normal probability methods
#
#   - Enables confidence intervals and hypothesis testing
#
#   - Works even when data isn’t normally distributed
#
# 7. What is the significance of confidence intervals in statistical analysis?
# - A confidence interval (CI) gives a range of values likely to contain the true population parameter.
#
# - A 95% CI means:
#
#   - If we repeated the sampling many times, 95% of the intervals would contain the true mean.
#
#   - It measures precision + reliability of estimates.
#
# 8. What is the concept of expected value in a probability distribution?
# - The expected value (mean) is the long-run average of a random variable.
#
# - For discrete:
#
# 𝐸
# (
# 𝑋
# )
# =
# ∑
# 𝑥
# 𝑃
# (
# 𝑥
# )
# E(X)=∑xP(x)
#
# - For continuous:
#
# 𝐸
# (
# 𝑋
# )
# =
# ∫
# 𝑥
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# E(X)=∫xf(x)dx
#
# - It represents the center of the distribution.
#
# 9. Write a Python program to generate 1000 random numbers from a normal distribution with mean = 50 and standard deviation = 5. Compute its mean and standard deviation using NumPy, and draw a histogram to visualize the distribution.
#
# - import numpy as np
#   import matplotlib.pyplot as plt
#
#   Generate data
#
#   data = np.random.normal(loc=50, scale=5, size=1000)
#
#   Compute mean and standard deviation
#
#   mean = np.mean(data)
#
#   std_dev = np.std(data)
#
#   print("Mean:", mean)
#
#   print("Standard Deviation:", std_dev)
#
#   Plot histogram
#
#   plt.hist(data, bins=30)
#
#   plt.title("Histogram of Normally Distributed Data")
#
#   plt.xlabel("Value")
#
#   plt.ylabel("Frequency")
#
#   plt.show()
#
# 10. You are working as a data analyst for a retail company. The company has collected daily sales data for 2 years and wants you to identify the overall sales trend.
# daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
# 235, 260, 245, 250, 225, 270, 265, 255, 250, 260]
#   Explain how you would apply the Central Limit Theorem to estimate the average sales with a 95% confidence interval.
#   Write the Python code to compute the mean sales and its confidence interval.
# - Even if daily sales are not normally distributed, CLT allows us to assume the sampling mean is approximately normal for large samples.
#   This lets us compute a 95% confidence interval for average daily sales:
#
# 𝐶
# 𝐼
# =
# 𝑥
# ˉ
# ±
# 𝑧
# ⋅
# 𝑠
# 𝑛
# CI=
# x
# ˉ
# ±z⋅
# n
# 	​
#
# s
# 	​
#
#
# - Where:
#
# 𝑧
# =
# 1.96
# z=1.96 for 95% confidence
#
# 𝑥
# ˉ
# x
# ˉ
#  = sample mean
#
# 𝑠
# s = sample standard deviation
#
# 𝑛
# n = sample size
#
# - import numpy as np
#   from math import sqrt
#
#   daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
#                235, 260, 245, 250, 225, 270, 265, 255, 250, 260]
#
#   Convert to NumPy array
#
#   sales = np.array(daily_sales)
#
#   Compute statistics
#
#   mean_sales = np.mean(sales)
#
#   std_sales = np.std(sales, ddof=1)
#
#   n = len(sales)
#
#   95% Confidence Interval
#
#   z = 1.96
#
#   margin_error = z * (std_sales / sqrt(n))
#
#   lower_bound = mean_sales - margin_error
#
#   upper_bound = mean_sales + margin_error
#
#   print("Mean Sales:", mean_sales)
#
#   print("95% Confidence Interval:", (lower_bound, upper_bound))
